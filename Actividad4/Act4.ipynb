# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as mplt

# %%
import pylab as plt

# %%
from matplotlib import rc

# %%
from pylab import figure, show, legend, xlabel, ylabel

# %%
df = pd.read_csv("/home/sofiagm/CompuDatos/Act4/15feb.csv",names=['PRES','HGHT','TEMP','DWPT','RELH','MIXR','DRCT','SKNT','THTA','THTE','THTV'])

# %%
df.head()
# Out:
#      PRES  HGHT  TEMP  DWPT  RELH  MIXR  DRCT SKNT   THTA   THTE   THTV
# 0  1002.0   137  10.4  10.4   100  7.96   320    5  283.4  305.5  284.8
# 1  1000.0   150  10.4  10.4   100  7.97   325    4  283.6  305.7  284.9
# 2   994.0   200  11.4  11.1    98  8.41   358    5  285.0  308.5  286.5
# 3   988.0   251  12.2  10.0    86  7.86    30    6  286.3  308.4  287.7
# 4   981.7   305  13.9   7.6    66  6.70    65    7  288.5  307.7  289.7

# %%
df.describe()
# Out:
#               PRES          HGHT        TEMP        DWPT        RELH  \
# count   127.000000    127.000000  127.000000  127.000000  127.000000
# mean    275.515748  15229.377953  -40.614961  -67.329921    9.267717
# std     319.364661   9736.883656   28.602989   32.409122   18.883288
# min       7.700000    137.000000  -72.500000  -95.100000    1.000000
# 25%      29.700000   6446.000000  -62.450000  -92.100000    1.000000
# 50%     121.200000  15240.000000  -51.900000  -83.600000    2.000000
# 75%     455.000000  23717.000000  -19.400000  -51.900000    6.500000
# max    1002.000000  32460.000000   19.600000   11.100000  100.000000
#
#              MIXR        THTA        THTE        THTV
# count  127.000000  127.000000  127.000000  127.000000
# mean     0.653858  459.570866  461.591339  459.688976
# std      1.715869  176.484353  174.870336  176.381904
# min      0.000000  283.400000  304.800000  284.800000
# 25%      0.000000  317.750000  318.100000  317.800000
# ...

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# PRES    0
# HGHT    0
# TEMP    0
# DWPT    0
# RELH    0
# MIXR    0
# DRCT    0
# SKNT    0
# THTA    0
# THTE    0
# THTV    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['PRES', 'HGHT', 'TEMP', 'DWPT', 'RELH', 'MIXR', 'DRCT', 'SKNT', 'THTA',
#        'THTE', 'THTV'],
#       dtype='object')

# %%
df.PRES= pd.to_numeric(df.PRES, errors='coerce')
df.HGHT= pd.to_numeric(df.HGHT, errors='coerce')
df.TEMP= pd.to_numeric(df.TEMP, errors='coerce')
df.DWPT= pd.to_numeric(df.DWPT, errors='coerce')

# %%
x=df[u'PRES']
y=df[u'HGHT']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.title('Presión vs. Altura')
plt.xlabel('Presión (hPa)')
plt.ylabel('Altura (m)')

# %%
plt.show()

# %%
x=df[u'TEMP']
y=df[u'HGHT']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.title('Temperatura vs. Altura')
plt.xlabel('Temperatura (°C)')
plt.ylabel('Altura (m)')

# %%
plt.show()

# %%
x=df[u'DWPT']
y=df[u'HGHT']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.title('Temperatura de Rocío vs. Altura')
plt.xlabel('Temperatura de Rocío (°C)')
plt.ylabel('Altura(m)')

# %%
plt.show()

# %%
x=df[u'TEMP']
y=df[u'HGHT']
mplt.plot(x,y)
mplt.grid(True)
plt.title('Temperatura y Temperatura de Rocío vs. Altura')

# %%
x=df[u'DWPT']
y=df[u'HGHT']
mplt.plot(x,y)
mplt.grid(True)

# %%
plt.show()

# %%
import os.path

# %%
import tephi as tph

# %%
dew_point = pd.read_csv("/home/sofiagm/CompuDatos/Act4/presvdwpt.csv", names=["Presión", "DWPT"])
dry_bulb = pd.read_csv("/home/sofiagm/CompuDatos/Act4/presvtemp.csv", names=["Presión", "TEMP"])
tpg = tph.Tephigram()
tpg.plot(dew_point)
tpg.plot(dry_bulb)
plt.title('Presión vs. Temperatura y Temperatura de Rocío')
plt.show()
