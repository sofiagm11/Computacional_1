# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from pylab import *

# %%
df=pd.read_csv("NOAA.csv",parse_dates=['Date Time'],header=int(0))

# %%
df.columns
# Out:
# Index(['Date Time', ' Water Level', ' Sigma', ' O', ' F', ' R', ' L',
#        ' Quality '],
#       dtype='object')

# %%
df.head()
# Out:
#             Date Time   Water Level   Sigma   O   F   R   L  Quality
# 0 2017-01-01 00:00:00         1.322   0.059   0   0   0   0         v
# 1 2017-01-01 00:06:00         1.385   0.069   0   0   0   0         v
# 2 2017-01-01 00:12:00         1.463   0.052   0   0   0   0         v
# 3 2017-01-01 00:18:00         1.470   0.069   0   0   0   0         v
# 4 2017-01-01 00:24:00         1.545   0.069   0   0   0   0         v

# %%
df.describe()
# Out:
#         Water Level        Sigma            O       F       R            L
# count   7440.000000  7440.000000  7440.000000  7440.0  7440.0  7440.000000
# mean       1.439835     0.077595     0.001075     0.0     0.0     0.002151
# std        1.021689     0.068233     0.032776     0.0     0.0     0.046327
# min       -1.260000     0.000000     0.000000     0.0     0.0     0.000000
# 25%        0.738000     0.026000     0.000000     0.0     0.0     0.000000
# 50%        1.486000     0.049000     0.000000     0.0     0.0     0.000000
# 75%        2.100750     0.108000     0.000000     0.0     0.0     0.000000
# max        5.079000     0.400000     1.000000     0.0     0.0     1.000000

# %%
df.columns=['Date Time','Water Level','Sigma','O','F','R','L','Quality']

# %%
df.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Date Time      0
# Water Level    0
# Sigma          0
# O              0
# F              0
# R              0
# L              0
# Quality        0
# dtype: int64

# %%
x=df["Date Time"]
y=df["Water Level"]

plt.title("Mareas en Montauk, Nueva York")
plt.ylabel('Nivel del agua (m)')
plt.xlabel('Fecha')
plt.grid(True)


plt.plot(x,y)

# %%
plt.show()
